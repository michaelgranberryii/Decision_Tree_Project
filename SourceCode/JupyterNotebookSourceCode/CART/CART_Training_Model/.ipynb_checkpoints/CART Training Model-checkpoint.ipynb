# %%
from chefboost import Chefboost as chef
import pandas as pd

# %%
df = pd.read_csv("dataSetTrain.csv")
newdf = df.iloc[:,1:9]
newdf
# Out:
#    How.far.do.you.commute.to.school.  \
# 0                         0-20 miles
# 1                        20-40 miles
# 2                        20-40 miles
# 3                         0-20 miles
# 4                        20-40 miles
# 5                         0-20 miles
# 6                         0-20 miles
# 7                        40-60 miles
# 8                        20-40 miles
# 9                        40-60 miles
# 10                        0-20 miles
# 11                       20-40 miles
# 12                       40-60 miles
# 13                        0-20 miles
# 14                        0-20 miles
# 15                       20-40 miles
# 16                       20-40 miles
# 17                       20-40 miles
# 18                         60-beyond
# 19                       40-60 miles
# 20                       40-60 miles
# 21                       20-40 miles
# 22                        0-20 miles
# 23                        0-20 miles
# ...

# %%
algo= ['ID3']
print(algo(0))
config = {'algorithm': algo(0)}
model = chef.fit(newdf, config = config, target_label = 'Do.you.prefer.in.person.or.online.learning.')
# Out:
# ['ID3']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-45053bc8606c> in <module>
#       2 print(algorithm)
#       3 config = {'algorithm': algorithm}
# ----> 4 model = chef.fit(newdf, config = config, target_label = 'Do.you.prefer.in.person.or.online.learning.')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/chefboost/Chefboost.py in fit(df, config, target_label, validation_df)
#     107
#     108         if algorithm not in valid_algorithms:
# --> 109                 raise ValueError('Invalid algorithm passed. You passed ', algorithm," but valid algorithms are ",valid_algorithms)
#     110
#     111         #------------------------
#
# ValueError: ('Invalid algorithm passed. You passed ', ['ID3'], ' but valid algorithms are ', ['ID3', 'C4.5', 'CART', 'CHAID', 'Regression'])
